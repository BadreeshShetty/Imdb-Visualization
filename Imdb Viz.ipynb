# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
imdb_1000=pd.read_csv("imdb_1000.csv")

# %%
imdb_1000.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                    actors_list
# 0        Tim Robbins,Morgan Freeman,Bob Gunton
# 1           Marlon Brando,Al Pacino,James Caan
# 2       Al Pacino,Robert De Niro,Robert Duvall
# 3    Christian Bale,Heath Ledger,Aaron Eckhart
# 4  John Travolta,Uma Thurman,Samuel L. Jackson

# %%
imdb_1000.shape
# Out:
# (979, 6)

# %%
imdb_1000.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974             Dustin Hoffman,Jessica Lange,Teri Garr
# 975  Michael J. Fox,Christopher Lloyd,Mary Steenburgen
# 976              Russell Crowe,Paul Bettany,Billy Boyd
# 977    JoBeth Williams,Heather ORourke,Craig T. Nelson
# ...

# %%
imdb_1000['duration'].mean()
# Out:
# 120.97957099080695

# %%
imdb_1000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
imdb_1000.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
imdb_1000.sort_values('duration')
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                           [Rec
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...

# %%
imdb_1000['duration'].plot(kind='hist',bins=10)
plt.show()

# %%
imdb_1000['duration'].plot(kind='box')
plt.show()

# %%
imdb_1000[imdb_1000['duration']==imdb_1000['duration'].max()]
# Out:
#      star_rating   title content_rating  genre  duration  \
# 476          7.8  Hamlet          PG-13  Drama       242
#
#                                      actors_list
# 476  Kenneth Branagh,Julie Christie,Derek Jacobi

# %%
imdb_1000[imdb_1000['duration']==imdb_1000['duration'].min()]
# Out:
#      star_rating   title content_rating  genre  duration  \
# 389          8.0  Freaks        UNRATED  Drama        64
#
#                                  actors_list
# 389  Wallace Ford,Leila Hyams,Olga Baclanova

# %%
imdb_1000[imdb_1000['duration'] >= 195]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 8            8.9                                Schindlers List
# 17           8.7                                  Seven Samurai
# 78           8.4                      Oncepon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3                Lagaan: Oncepon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 335          8.0                                 Doctor Zhivago
# 385          8.0                                      Spartacus
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# ...

# %%
content=imdb_1000.groupby('content_rating')['star_rating'].value_counts()
print(content)
# Out:
# content_rating  star_rating
# APPROVED        8.1            12
#                 7.8             6
#                 8.4             6
#                 7.9             4
#                 8.0             4
#                 7.5             3
#                 7.6             3
#                 7.7             3
#                 8.3             2
#                 8.5             2
#                 8.6             1
#                 8.7             1
# G               8.0             6
#                 7.6             3
#                 7.7             3
#                 7.8             3
#                 8.1             3
#                 8.2             3
#                 8.3             3
#                 7.9             2
#                 8.4             2
#                 7.4             1
#                 7.5             1
#                 8.5             1
#                 8.6             1
# GP              7.7             1
# ...

# %%
content=imdb_1000[['content_rating','title']].groupby('content_rating').count()
print(content)
# Out:
#                 title
# content_rating
# APPROVED           47
# G                  32
# GP                  3
# NC-17               7
# NOT RATED          65
# PASSED              7
# PG                123
# PG-13             189
# R                 460
# TV-MA               1
# UNRATED            38
# X                   4

# %%
content.head()
# Out:
#                 title
# content_rating
# APPROVED           47
# G                  32
# GP                  3
# NC-17               7
# NOT RATED          65

# %%
content.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, APPROVED to X
# Data columns (total 1 columns):
# title    12 non-null int64
# dtypes: int64(1)
# memory usage: 192.0+ bytes

# %%
content.plot(kind='bar',title='Content Rating Visualization')
plt.xlabel('Content Rating')
plt.ylabel('Title Count')
plt.show()

# %%
imdb_1000[(imdb_1000['content_rating']=='PG-13') & (imdb_1000['duration'] > 142) & (imdb_1000['star_rating']>=8.0)].sort_values('star_rating')
# Out:
#      star_rating                                              title  \
# 385          8.0                                          Spartacus
# 373          8.0                                    My Name Is Khan
# 362          8.0                    The Hobbit: Annexpected Journey
# 359          8.0                The Hobbit: The Desolation of Smaug
# 341          8.0                                     Cinderella Man
# 339          8.0                                 Dances with Wolves
# 335          8.0                                     Doctor Zhivago
# 380          8.0                                      Casino Royale
# 271          8.1  Pirates of the Caribbean: The Curse of the Bla...
# 259          8.1                                           The Help
# 177          8.2                                       The Avengers
# 43           8.5                              The Dark Knight Rises
# 60           8.5                                           3 Idiots
# ...

# %%
imdb_1000.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
imdb_1000['content_rating'].isnull().sum()
# Out:
# 3

# %%
imdb_1000[imdb_1000['content_rating'].isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                actors_list
# 187  Biography       110  Paul Newman,Robert Redford,Katharine Ross
# 649     Action       158       Richard Burton,Clint Eastwood,Maryre
# 936  Adventure       128         John Wayne,Kim Darby,Glen Campbell

# %%
imdb_1000.at[(187,649),'content_rating']='PG'
imdb_1000.at[(936),'content_rating']='PG-13'

# %%
imdb_1000.iloc[[187,649,936],:]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid             PG
# 649          7.7                   Where Eagles Dare             PG
# 936          7.4                           True Grit          PG-13
#
#          genre  duration                                actors_list
# 187  Biography       110  Paul Newman,Robert Redford,Katharine Ross
# 649     Action       158       Richard Burton,Clint Eastwood,Maryre
# 936  Adventure       128         John Wayne,Kim Darby,Glen Campbell

# %%
imdb_1000.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    0
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
check=imdb_1000[(imdb_1000['duration']>120) & (imdb_1000['star_rating']>=imdb_1000['star_rating'].mean())]
print(check)
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 6            8.9                       The Good, the Bad and thegly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                    Schindlers List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                       Forrest Gump
# ...

# %%
imdb_1000.boxplot(column="duration",by="star_rating")
plt.show()

# %%
imdb_1000.boxplot(column="duration",by="content_rating")
plt.show()

# %%
imdb_1000.sort_values('star_rating',ascending=False).groupby('genre')['title','star_rating'].first()
# Out:
#                                                    title  star_rating
# genre
# Action                                   The Dark Knight          9.0
# Adventure  The Lord of the Rings: The Return of the King          8.9
# Animation                                  Spirited Away          8.6
# Biography                                Schindlers List          8.9
# Comedy                                      Modern Times          8.6
# Crime                           The Shawshank Redemption          9.3
# Drama                                       12 Angry Men          8.9
# Family                        E.T. the Extra-Terrestrial          7.9
# Fantasy                        The City of Lost Children          7.7
# Film-Noir                                  The Third Man          8.3
# History                              Battleship Potemkin          8.0
# Horror                                            Psycho          8.6
# ...

# %%
genres = imdb_1000['genre'].value_counts()[imdb_1000['genre'].value_counts() > 10].index
imdb_1000[imdb_1000['genre'].isin(genres)].groupby('genre')['star_rating'].mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %%
#Apply that function to every entry    
movies_series = imdb_1000['actors_list']
#Declare a list to store the split values
actors_list = []
for movie_actors in movies_series:
    actors_list.append([e.strip() for e in movie_actors.split(',')])
#Declare a dictionary and see if the actor name key exist and then count accordingly.
actor_dict = {}
for actor in actors_list:
    for a in actor:
        if a in actor_dict:
            actor_dict[a] +=1
        else:
            actor_dict[a] = 1

actor_dict
sorted(actor_dict.items(), key=lambda x: x[0])
# Out:
# [('Aamir Khan', 5),
#  ('Aaron Eckhart', 2),
#  ('Aaron Taylor-Johnson', 1),
#  ('Abbie Cornish', 1),
#  ('Abigail Breslin', 1),
#  ('Ad\\xe8le Exarchopoulos', 1),
#  ('Adam Bryant', 1),
#  ('Adam Driver', 1),
#  ('Adam Levine', 1),
#  ('Adam Sandler', 1),
#  ('Adel Bencherif', 1),
#  ('Adil Hussain', 1),
#  ('Adolphe Menjou', 1),
#  ('Adriana Caselotti', 1),
#  ('Adrien Brody', 2),
#  ('Agame Malembo-Emene', 1),
#  ('Ahmad Khan Mahmoodzada', 1),
#  ('Aidan Quinn', 1),
#  ('Aitana S\\xe1nchez-Gij\\xf3n', 1),
#  ('Akemi Yamaguchi', 1),
#  ('Aki Maeda', 1),
#  ('Akio \\xd4tsuka', 1),
#  ('Akira Terao', 1),
#  ('Aksel Hennie', 1),
#  ('Akshaye Khanna', 1),
#  ('Al Pacino', 13),
#  ('Alain Delon', 1),
#  ('Alan Ladd', 1),
#  ('Alan Rickman', 3),
#  ('Alan Ruck', 1),
#  ('Alan Tudyk', 1),
#  ('Albert Brooks', 1),
#  ('Albert Finney', 2),
#  ('Albert R\\xe9my', 1),
#  ('Alec Baldwin', 5),
#  ('Alec Cawthorne', 1),
#  ('Alec Guinness', 2),
#  ('Alec McCowen', 1),
# ...
